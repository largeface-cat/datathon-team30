# %%
import pandas as pd
import numpy as np

# %%
acs_5yr = pd.read_csv("./acs_5yr_est_selected_economic_characteristics_2010-2022.csv")
acs_5yr.head()
# Out:
#                Label (Grouping)           Category    State   Estimate  \
# 0             EMPLOYMENT STATUS             Header  Alabama        NaN
# 1  Population 16 years and over  EMPLOYMENT STATUS  Alabama  3,714,504
# 2                In labor force  EMPLOYMENT STATUS  Alabama  2,246,848
# 3          Civilian labor force  EMPLOYMENT STATUS  Alabama  2,230,879
# 4                      Employed  EMPLOYMENT STATUS  Alabama  2,036,867
#
#   Margin of Error    Percent Percent Margin of Error  Year
# 0             NaN        NaN                     NaN  2010
# 1          ±1,588  3,714,504                     (X)  2010
# 2          ±5,576      60.5%                    ±0.1  2010
# 3          ±5,531      60.1%                    ±0.1  2010
# 4          ±5,904      54.8%                    ±0.2  2010

# %%
acs_5yr['Label (Grouping)']
# Out:
# 0                              EMPLOYMENT STATUS
# 1                   Population 16 years and over
# 2                                 In labor force
# 3                           Civilian labor force
# 4                                       Employed
#                           ...
# 98015                          18 years and over
# 98016                             18 to 64 years
# 98017                          65 years and over
# 98018                         People in families
# 98019    Unrelated individuals 15 years and over
# Name: Label (Grouping), Length: 98020, dtype: object

# %%
labels = acs_5yr['Label (Grouping)'].values
np.unique(labels)
# Out:
# array(['$10,000 to $14,999', '$100,000 to $149,999', '$15,000 to $24,999',
#        '$150,000 to $199,999', '$200,000 or more', '$25,000 to $34,999',
#        '$35,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999',
#        '18 to 64 years', '18 years and over', '65 years and over',
#        'CLASS OF WORKER', 'COMMUTING TO WORK',
#        'Civilian employed population 16 years and over',
#        'Civilian noninstitutionalized population 18 to 64 years',
#        'Civilian noninstitutionalized population 19 to 64 years',
#        'Civilian noninstitutionalized population under 18 years',
#        'Civilian noninstitutionalized population under 19 years',
#        'EMPLOYMENT STATUS', 'Females 16 years and over',
#        'HEALTH INSURANCE COVERAGE',
#        'INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2011 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2012 INFLATION-ADJUSTED DOLLARS)',
# ...

# %%
for i in np.unique(labels):
    cnt = 0
    for j in labels:
        if i == j: cnt += 1
    print(cnt)
# Out:
# 1352
# 1352
# 1352
# 1352
# 1352
# 1352
# 1352
# 1352
# 1352
# 676
# 676
# 676
# 676
# 676
# 2028
# 364
# 312
# 364
# 312
# 676
# 676
# 676
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 676
# 1352
# 676
# 260
# 416
# 416
# 260
# 676
# 676
# 260
# 416
# 416
# 416
# 260
# 260
# 676
# 676
# 676
# 1248
# 1248
# 780
# 780
# 676
# 156
# 676
# 312
# 676
# 156
# 156
# 156
# 676
# 676
# 156
# 156
# 676
# 468
# 156
# 156
# 312
# 156
# 156
# 156
# 156
# 468
# 156
# 156
# 156
# 364
# 676
# 676
# 676
# 156
# 156
# 156
# 156
# 312
# 676
# 156
# 156
# 156
# 156
# 312
# 624
# 156
# 156
# 156
# 156
# 156
# 156
# 156
# 156
# 156
# 156
# 676
# 156
# 156
# 156
# 156
# 364
# 364
# 364
# 364
# 156
# 364
# 156
# 520
# 1040
# 156
# 520
# 520
# 520
# 312
# 520
# 520
# 156
# 208
# 520
# 520
# 1040
# 520
# 520
# 520
# 520
# 208
# 364
# 364
# 364
# 364
# 520
# 520
# 520
# 364
# 312
# 520
# 520
# 520
# 520
# 1196
# 520
# 520
# 520
# 520
# 364
# 52
# 104
# 520
# 520
# 520
# 520
# 520
# 520
# ...

# %%
import re

pattern = r"(.*INCOME.*)"
for i in acs_5yr['Category']:
    print(re.findall(pattern, i))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ['INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)']
# ...
